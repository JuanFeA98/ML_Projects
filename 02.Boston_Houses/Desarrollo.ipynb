# %% [markdown]
# ## **Librerías**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = False

# %%
from scipy.stats import pearsonr

# %% [markdown]
# ## **Datos**

# %%
df = pd.read_csv('./Data/train.csv')

# %%
def exploracion_metadatos(df, y):
    # Obtenemos nuestras variables y sus tipos
    meta = pd.DataFrame(df.dtypes).reset_index()
    meta.columns = ['Variable', 'Tip']    

    # Calculamos algunos metadatos de nuestra data
    meta['Observaciones'] = meta['Variable'].apply(lambda x: df[x].count())
    meta['Valores_Unicos'] = meta['Variable'].apply(lambda x: len(df[x].unique()))
    meta['Valores_Nulos'] = meta['Variable'].apply(lambda x: df[x].isnull().sum())
    meta['%_Valores_Nulos'] = round(meta['Valores_Nulos']/df.shape[0]*100, 2)
    
    # Calculamos algunos valores adicionales
    
    # Kurtosis
    kurtosis = pd.DataFrame(df.kurt(numeric_only=True)).reset_index()
    kurtosis.columns = ['Variable', 'Kurtosis']
    
    # Inclinación
    skewness = pd.DataFrame(df.skew(numeric_only=True)).reset_index()
    skewness.columns = ['Variable', 'Skewness']
    
    # Correlación
    corr = df.corr().reset_index()[['index', y]]
    corr.columns = ['Variable', 'Correlacion']
    corr['Correlacion'] = corr['Correlacion'].apply(lambda x: abs(x))
    
    meta = pd.merge(meta, kurtosis, how='left')
    meta = pd.merge(meta, skewness, how='left')
    meta = pd.merge(meta, corr, how='left')

    return meta

# %%
meta = exploracion_metadatos(df, 'SalePrice')
meta.tail(3)
# Out:
#          Variable     Tip  Observaciones  Valores_Unicos  ...  %_Valores_Nulos  Kurtosis  Skewness  Correlacion
# 78       SaleType  object           1460               9  ...              0.0       NaN       NaN          NaN
# 79  SaleCondition  object           1460               6  ...              0.0       NaN       NaN          NaN
# 80      SalePrice   int64           1460             663  ...              0.0  6.536282  1.882876          1.0
#
# [3 rows x 9 columns]

# %%
meta[~meta['Correlacion'].isna()].sort_values('Correlacion', ascending = False)
# Out:
#          Variable      Tip  Observaciones  Valores_Unicos  ...  %_Valores_Nulos    Kurtosis   Skewness  Correlacion
# 80      SalePrice    int64           1460             663  ...             0.00    6.536282   1.882876     1.000000
# 17    OverallQual    int64           1460              10  ...             0.00    0.096293   0.216944     0.790982
# 46      GrLivArea    int64           1460             861  ...             0.00    4.895121   1.366560     0.708624
# 61     GarageCars    int64           1460               5  ...             0.00    0.220998  -0.342549     0.640409
# 62     GarageArea    int64           1460             441  ...             0.00    0.917067   0.179981     0.623431
# 38    TotalBsmtSF    int64           1460             721  ...             0.00   13.250483   1.524255     0.613581
# 43       1stFlrSF    int64           1460             753  ...             0.00    5.745841   1.376757     0.605852
# 49       FullBath    int64           1460               4  ...             0.00   -0.857043   0.036562     0.560664
# 54   TotRmsAbvGrd    int64           1460              12  ...             0.00    0.880762   0.676341     0.533723
# 19      YearBuilt    int64           1460             112  ...             0.00   -0.439552  -0.613461     0.522897
# 20   YearRemodAdd    int64           1460              61  ...             0.00   -1.272245  -0.503562     0.507101
# 59    GarageYrBlt  float64           1379              98  ...             5.55   -0.418341  -0.649415     0.486362
# 26     MasVnrArea  float64           1452             328  ...             0.55   10.082417   2.669084     0.477493
# 56     Fireplaces    int64           1460               4  ...             0.00   -0.217237   0.649565     0.466929
# 34     BsmtFinSF1    int64           1460             637  ...             0.00   11.118236   1.685503     0.386420
# 3     LotFrontage  float64           1201             111  ...            17.74   17.452867   2.163569     0.351799
# 66     WoodDeckSF    int64           1460             274  ...             0.00    2.992951   1.541376     0.324413
# 44       2ndFlrSF    int64           1460             417  ...             0.00   -0.553464   0.813030     0.319334
# 67    OpenPorchSF    int64           1460             202  ...             0.00    8.490336   2.364342     0.315856
# 50       HalfBath    int64           1460               3  ...             0.00   -1.076927   0.675897     0.284108
# 4         LotArea    int64           1460            1073  ...             0.00  203.243271  12.207688     0.263843
# 47   BsmtFullBath    int64           1460               4  ...             0.00   -0.839098   0.596067     0.227122
# 37      BsmtUnfSF    int64           1460             780  ...             0.00    0.474994   0.920268     0.214479
# 51   BedroomAbvGr    int64           1460               8  ...             0.00    2.230875   0.211790     0.168213
# 52   KitchenAbvGr    int64           1460               4  ...             0.00   21.532404   4.488397     0.135907
# 68  EnclosedPorch    int64           1460             120  ...             0.00   10.430766   3.089872     0.128578
# 70    ScreenPorch    int64           1460              76  ...             0.00   18.439068   4.122214     0.111447
# 71       PoolArea    int64           1460               8  ...             0.00  223.268499  14.828374     0.092404
# 1      MSSubClass    int64           1460              15  ...             0.00    1.580188   1.407657     0.084284
# 18    OverallCond    int64           1460               9  ...             0.00    1.106413   0.693067     0.077856
# 76         MoSold    int64           1460              12  ...             0.00   -0.404109   0.212053     0.046432
# 69      3SsnPorch    int64           1460              20  ...             0.00  123.662379  10.304342     0.044584
# 77         YrSold    int64           1460               5  ...             0.00   -1.190601   0.096269     0.028923
# 45   LowQualFinSF    int64           1460              24  ...             0.00   83.234817   9.011341     0.025606
# 0              Id    int64           1460            1460  ...             0.00   -1.200000   0.000000     0.021917
# 75        MiscVal    int64           1460              21  ...             0.00  701.003342  24.476794     0.021190
# 48   BsmtHalfBath    int64           1460               3  ...             0.00   16.396642   4.103403     0.016844
# 36     BsmtFinSF2    int64           1460             144  ...             0.00   20.113338   4.255261     0.011378
#
# [38 rows x 9 columns]

# %%
df['HalfBath'].hist()
# Out:
# <AxesSubplot:>

# %%
df[['HalfBath']].describe()
# Out:
#           HalfBath
# count  1460.000000
# mean      0.382877
# std       0.502885
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       2.000000
